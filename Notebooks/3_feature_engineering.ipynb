# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import scipy.stats # For finding skew in the dataset

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read in Data

# %%
# Set working directory
# %cd C:/Users/sriha/OneDrive/Desktop/DS/My work/life-expectancy

# Unpickle preprocessed training data
X_train = pd.read_pickle('Data/X_train_clean.pkl')

# Unpickle train target variable
y_train = pd.read_pickle('Data/y_train.pkl')

# Unpickle preprocessed test data
X_test = pd.read_pickle('Data/X_test_clean.pkl')

# Unpickle train target variable
y_test = pd.read_pickle('Data/y_test.pkl')

# Combine X and y for visualization and to determine correlations
df_train = X_train.join(y_train)

df_test = X_test.join(y_test)
# Out:
# C:\Users\sriha\OneDrive\Desktop\DS\My work\life-expectancy

# %%
df_train
# Out:
#          Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 615        Congo  2008  Developing            338.0            8.0     2.58
# 2909      Zambia  2012  Developing            349.0           29.0     2.59
# 2812     Uruguay  2013  Developing            117.0            1.0     5.82
# 1825       Nepal  2003  Developing             22.0           38.0     0.20
# 497       Canada  2014  Developing             65.0            2.0     8.10
# ...          ...   ...         ...              ...            ...      ...
# 599      Comoros  2008  Developing            255.0            2.0     0.12
# 1601    Malaysia  2000  Developing            149.0            4.0     0.54
# 1363       Kenya  2014  Developing            255.0           56.0     0.01
# 1549  Luxembourg  2004   Developed             92.0            0.0    12.42
# 865      Eritrea  2000  Developing            593.0            7.0     0.83
#
#       percentage expenditure  Hepatitis B  Measles   under-five deaths   ...  \
# 615                 0.000000         73.0         2                11.0  ...
# 2909              196.915250         78.0       896                43.0  ...
# 2812              482.803945         94.0         0                 1.0  ...
# 1825                2.790965          2.0     13344                50.0  ...
# 497               102.190217         55.0       418                 2.0  ...
# ...                      ...          ...       ...                 ...  ...
# 599                93.367890         81.0         0                 2.0  ...
# 1601               23.371672         97.0      6187                 5.0  ...
# 1363              170.962662         92.0       354                79.0  ...
# 1549            12372.051880         94.0         0                 0.0  ...
# 865                 0.735940         94.0       789                10.0  ...
#
#       Total expenditure  Diphtheria    HIV/AIDS           GDP  Population  \
# 615                2.90         79.0        4.3   1598.782861   1558177.0
# 2909               4.91         78.0        5.6   1734.936120  14699937.0
# 2812               8.68         94.0        0.1  16881.256800      3485.0
# 1825               5.48         78.0        0.1    253.724120   2495623.0
# 497                1.45         91.0        0.1    544.433760  35544564.0
# ...                 ...          ...        ...           ...         ...
# 599                5.13         81.0        0.1    795.975190    657229.0
# 1601               3.40         98.0        0.1    445.174710   2318568.0
# 1363               5.72         92.0        2.9   1335.645800    462425.0
# 1549               8.20         99.0        0.1  75716.351800     45895.0
# 865                4.43         81.0        1.9     28.196949    339281.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 615                     8.4                  8.0
# 2909                    6.5                  6.3
# 2812                    1.5                  1.4
# 1825                   18.0                 18.6
# 497                     0.5                  0.5
# ...                     ...                  ...
# 599                     7.2                  7.1
# 1601                    9.8                  9.6
# 1363                    7.8                  7.7
# 1549                    1.0                  0.9
# 865                     1.2                  1.1
#
#       Income composition of resources  Schooling  Life expectancy
# 615                             0.527       10.0              59.4
# 2909                            0.554       12.3              59.2
# 2812                            0.788       15.5              76.8
# 1825                            0.457        9.2              64.3
# 497                             0.912       15.9              82.0
# ...                               ...        ...               ...
# 599                             0.461       10.2              61.0
# 1601                            0.715       11.6              72.4
# 1363                            0.546       11.1              62.9
# 1549                            0.867       13.5              78.7
# 865                             0.000        3.9              45.3
#
# [2196 rows x 21 columns]

# %%
df_test
# Out:
#                                  Country  Year      Status  Adult Mortality  \
# 1831                         Netherlands  2013   Developed              6.0
# 893                             Ethiopia  2004  Developing            354.0
# 1800                             Namibia  2011  Developing            268.0
# 56                                Angola  2007  Developing            375.0
# 2860  Venezuela (Bolivarian Republic of)  2013  Developing            159.0
# ...                                  ...   ...         ...              ...
# 2704                        Turkmenistan  2008  Developing            235.0
# 1945                            Pakistan  2012  Developing            165.0
# 1364                               Kenya  2013  Developing            258.0
# 1920                              Norway  2005   Developed             73.0
# 2705                        Turkmenistan  2007  Developing            241.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 1831            1.0     8.68             1475.030397         51.0      2632
# 893           217.0     0.86                1.506962         70.5        73
# 1800            3.0     7.84                7.896235         82.0        79
# 56             87.0     6.35              184.821345         73.0      1014
# 2860            9.0     6.71                0.000000         82.0         0
# ...             ...      ...                     ...          ...       ...
# 2704            6.0     2.40               34.239794         96.0         0
# 1945          369.0     0.04               59.659001         72.0      8046
# 1364           58.0     1.84              165.930498         93.0       190
# 1920            0.0     6.37            11792.534650         92.0         0
# 2705            6.0     2.58                0.358651         98.0        59
#
#       under-five deaths   ...  Total expenditure  Diphtheria    HIV/AIDS  \
# 1831                 1.0  ...              11.40         97.0        0.1
# 893                342.0  ...               4.23          4.0        4.1
# 1800                 4.0  ...               8.78         82.0        4.7
# 56                 138.0  ...               3.38         73.0        2.6
# 2860                10.0  ...               4.94         82.0        0.1
# ...                  ...  ...                ...          ...        ...
# 2704                 8.0  ...               1.93         96.0        0.1
# 1945               456.0  ...               2.76         72.0        0.1
# 1364                81.0  ...               5.57         87.0        3.0
# 1920                 0.0  ...               8.89         91.0        0.1
# 2705                 8.0  ...               2.16         98.0        0.1
#
#                GDP   Population   thinness  1-19 years   thinness 5-9 years  \
# 1831  51574.489420    1684432.0                    1.0                  0.9
# 893     135.762386    7462445.0                   11.5                 11.3
# 1800     56.971392    2215621.0                    9.9                  9.9
# 56     2878.837144    2997687.0                    9.6                  9.6
# 2860   2315.317990    1794997.0                    1.6                  1.5
# ...            ...          ...                    ...                  ...
# 2704    394.467675    4935762.0                    3.2                  3.3
# 1945   1261.289670  177911533.0                   19.8                  2.2
# 1364   1229.114798   44826849.0                    7.9                  7.7
# 1920  66775.394400    4623291.0                    0.8                  0.7
# 2705     26.371428     487137.0                    3.3                  3.3
#
#       Income composition of resources  Schooling  Life expectancy
# 1831                            0.922       18.1              81.4
# 893                             0.310        5.4              55.0
# 1800                            0.612       11.5              64.3
# 56                              0.454        7.7              48.2
# 2860                            0.770       14.2              73.8
# ...                               ...        ...               ...
# 2704                            0.000       10.5              64.5
# 1945                            0.529        7.6              65.7
# 1364                            0.541       11.1              62.6
# 1920                            0.929       17.6              81.0
# 2705                            0.000       10.4              64.1
#
# [732 rows x 21 columns]

# %% [markdown]
# # Understanding the Features

# %%
corr1 = df_train.corr()['Life expectancy '].sort_values(ascending=False)
corr1
# Out:
# Life expectancy                    1.000000
# Schooling                          0.717465
# Income composition of resources    0.686854
# Diphtheria                         0.480411
# Polio                              0.463695
# GDP                                0.436806
# Alcohol                            0.408507
# percentage expenditure             0.390879
# Hepatitis B                        0.274899
# Total expenditure                  0.198799
# Year                               0.170944
# Population                        -0.033021
# Measles                           -0.160167
# infant deaths                     -0.195151
# under-five deaths                 -0.220623
#  thinness 5-9 years               -0.460253
#  thinness  1-19 years             -0.468309
#  HIV/AIDS                         -0.560830
# Adult Mortality                   -0.691349
# Name: Life expectancy , dtype: float64

# %% [markdown]
# # Feature Engineering
#
# ### 1. Transformation
#
# - EDA revealed that many features were skewed (i.e. not normally distributed). Here we will use scipy.stats to figure out which features are skewed and apply a log transform to reduce the skew. There are other methods to deal with skew, but we will stick to this simple method for now.
#
# - Applying the log transform did help reduce the skew, which is likely to improve performance.
#
# - Of note, based on our criteria, the target variable was not transformed, so we will not have to apply an inverse log pprior to making predictions.
#
#
#
# ### 2. Encoding
#
# - We have one categorical feature ('Status') which we will encode
#
# ### 3. Feature selection
#
# - EDA reveled that some features were strongly correlated to each other. We may later choose to drop these features to improve performance. For now we will leave them in.

# %%
def find_skew(dataset, show=True, col_names=False):
  df_skew = pd.DataFrame(dataset.select_dtypes(np.number).columns, columns=['Feature'])
  df_skew['Skew'] = df_skew['Feature'].apply(lambda feature: scipy.stats.skew(dataset[feature]))
  df_skew['Absolute Skew'] = df_skew['Skew'].apply(abs)
  df_skew['Skewed'] = df_skew['Absolute Skew'].apply(lambda x: True if x >= 0.65 else False)

  if show:
    from IPython.display import display
    display(df_skew)

  if col_names:
    return df_skew[df_skew['Absolute Skew'] >= 0.65]['Feature'].values

find_skew(df_train)
# Out:
#                             Feature       Skew  Absolute Skew  Skewed
# 0                              Year   0.005945       0.005945   False
# 1                   Adult Mortality   1.210173       1.210173    True
# 2                     infant deaths   9.987366       9.987366    True
# 3                           Alcohol   0.623417       0.623417   False
# 4            percentage expenditure   4.414371       4.414371    True
# 5                       Hepatitis B  -1.897139       1.897139    True
# 6                          Measles    8.600302       8.600302    True
# 7                under-five deaths    9.615902       9.615902    True
# 8                             Polio  -2.032545       2.032545    True
# 9                 Total expenditure   0.644501       0.644501   False
# 10                      Diphtheria   -2.016328       2.016328    True
# 11                         HIV/AIDS   5.158308       5.158308    True
# 12                              GDP   3.347138       3.347138    True
# 13                       Population  17.775879      17.775879    True
# 14             thinness  1-19 years   1.682692       1.682692    True
# 15               thinness 5-9 years   1.751541       1.751541    True
# 16  Income composition of resources  -1.168408       1.168408    True
# 17                        Schooling  -0.589551       0.589551   False
# 18                 Life expectancy   -0.627243       0.627243   False

# %%
df = df_train.copy()
skewed_cols = find_skew(df, show=False, col_names=True)

for col in skewed_cols:
  df[col] = np.log1p(df[col])

find_skew(df)
# Out:
#                             Feature      Skew  Absolute Skew  Skewed
# 0                              Year  0.005945       0.005945   False
# 1                   Adult Mortality -1.085829       1.085829    True
# 2                     infant deaths  0.688420       0.688420    True
# 3                           Alcohol  0.623417       0.623417   False
# 4            percentage expenditure -0.079912       0.079912   False
# 5                       Hepatitis B -3.031565       3.031565    True
# 6                          Measles   0.533985       0.533985   False
# 7                under-five deaths   0.632524       0.632524   False
# 8                             Polio -3.172760       3.172760    True
# 9                 Total expenditure  0.644501       0.644501   False
# 10                      Diphtheria  -3.162834       3.162834    True
# 11                         HIV/AIDS  2.097994       2.097994    True
# 12                              GDP -0.102777       0.102777   False
# 13                       Population -0.688636       0.688636    True
# 14             thinness  1-19 years  0.136098       0.136098   False
# 15               thinness 5-9 years  0.110380       0.110380   False
# 16  Income composition of resources -1.672156       1.672156    True
# 17                        Schooling -0.589551       0.589551   False
# 18                 Life expectancy  -0.627243       0.627243   False

# %%
del df

# %% [markdown]
# # Create EngineerFeatures Object

# %%
class EngineerFeatures():

    def __init__(self):
        pass

    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None): 
        X_new = X.copy()

        # Drop uncorrelated or unimportant features
        cols_to_drop = [
            'Country', # This column cannot be encoded and doesn't carry any useful information
            'Population' # Very weak correaltion to target variable
            
        ]
        X_new = X_new.drop(cols_to_drop, axis=1)

        # Feature transformations for numeric features
        # Note that skewed columns will have to be entered manually here 
        skewed_cols = [
            'Adult Mortality',
            'infant deaths', 
            'percentage expenditure', 
            'Hepatitis B',
            'Measles ', 
            'under-five deaths ',
            'Polio',
            'Diphtheria ', 
            ' HIV/AIDS', 
            'GDP',
            ' thinness  1-19 years', 
            ' thinness 5-9 years',
            'Income composition of resources'
        ]

        for col in skewed_cols:
            X_new[col] = np.log1p(X_new[col])

        # Feature encoding
        cols_to_encode = [
            'Status'
        ]
        
        X_new = pd.get_dummies(X_new, columns=cols_to_encode, drop_first=True)

        return X_new

    def fit_transform(self, X, y=None):
        return self.fit(X).transform(X)

# %%
engg = EngineerFeatures()

df_train_engineered = engg.fit_transform(df_train)
df_test_engineered = engg.transform(df_test)

# %%
# Note that the targeet variable is unchanged, so we can proceed with saving just the features
X_train_engineered = df_train_engineered.drop('Life expectancy ', axis=1)
X_test_engineered = df_test_engineered.drop('Life expectancy ', axis=1)

# %%
X_train_engineered.head()
# Out:
#       Year  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 615   2008         5.826000       2.197225     2.58                0.000000
# 2909  2012         5.857933       3.401197     2.59                5.287839
# 2812  2013         4.770685       0.693147     5.82                6.181680
# 1825  2003         3.135494       3.663562     0.20                1.332621
# 497   2014         4.189655       1.098612     8.10                4.636574
#
#       Hepatitis B  Measles   under-five deaths      Polio  Total expenditure  \
# 615      4.304065  1.098612            2.484907  4.356709               2.90
# 2909     4.369448  6.799056            3.784190  2.079442               4.91
# 2812     4.553877  0.000000            0.693147  4.553877               8.68
# 1825     1.098612  9.498897            3.931826  4.343805               5.48
# 497      4.025352  6.037871            1.098612  4.521789               1.45
#
#       Diphtheria    HIV/AIDS       GDP   thinness  1-19 years  \
# 615      4.382027   1.667707  7.377623               2.240710
# 2909     4.369448   1.887070  7.459302               2.014903
# 2812     4.553877   0.095310  9.734018               0.916291
# 1825     4.369448   0.095310  5.540181               2.944439
# 497      4.521789   0.095310  6.301581               0.405465
#
#        thinness 5-9 years  Income composition of resources  Schooling  \
# 615              2.197225                         0.423305       10.0
# 2909             1.987874                         0.440832       12.3
# 2812             0.875469                         0.581098       15.5
# 1825             2.975530                         0.376380        9.2
# 497              0.405465                         0.648150       15.9
#
#       Status_Developing
# 615                   1
# 2909                  1
# 2812                  1
# 1825                  1
# 497                   1

# %%
X_test_engineered.head()
# Out:
#       Year  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 1831  2013         1.945910       0.693147     8.68                7.297112
# 893   2004         5.872118       5.384495     0.86                0.919072
# 1800  2011         5.594711       1.386294     7.84                2.185628
# 56    2007         5.929589       4.477337     6.35                5.224786
# 2860  2013         5.075174       2.302585     6.71                0.000000
#
#       Hepatitis B  Measles   under-five deaths      Polio  Total expenditure  \
# 1831     3.951244  7.875879            0.693147  4.584967              11.40
# 893      4.269697  4.304065            5.837730  4.007333               4.23
# 1800     4.418841  4.382027            1.609438  4.454347               8.78
# 56       4.304065  6.922644            4.934474  4.330733               3.38
# 2860     4.418841  0.000000            2.397895  4.418841               4.94
#
#       Diphtheria    HIV/AIDS        GDP   thinness  1-19 years  \
# 1831     4.584967   0.095310  10.850802               0.693147
# 893      1.609438   1.629241   4.918245               2.525729
# 1800     4.418841   1.740466   4.059950               2.388763
# 56       4.304065   1.280934   7.965489               2.360854
# 2860     4.418841   0.095310   7.747734               0.955511
#
#        thinness 5-9 years  Income composition of resources  Schooling  \
# 1831             0.641854                         0.653366       18.1
# 893              2.509599                         0.270027        5.4
# 1800             2.388763                         0.477476       11.5
# 56               2.360854                         0.374318        7.7
# 2860             0.916291                         0.570980       14.2
#
#       Status_Developing
# 1831                  0
# 893                   1
# 1800                  1
# 56                    1
# 2860                  1

# %% [markdown]
# # Save Engineered Data

# %%
# pickle engineered train data
X_train_engineered.to_pickle('Data/X_train_engineered.pkl')

# pickle engineered test data
X_test_engineered.to_pickle('Data/X_test_engineered.pkl')
