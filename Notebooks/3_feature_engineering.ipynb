# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import scipy.stats # For finding skew in the dataset

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read in Data

# %%
# Set working directory
# %cd C:/Users/sriha/OneDrive/Desktop/DS/My work/life-expectancy

# Unpickle preprocessed training data
X_train = pd.read_pickle('Data/X_train_clean.pkl')

# Unpickle train target variable
y_train = pd.read_pickle('Data/y_train.pkl')

# Unpickle preprocessed test data
X_test = pd.read_pickle('Data/X_test_clean.pkl')

# Unpickle train target variable
y_test = pd.read_pickle('Data/y_test.pkl')

# Combine X and y for visualization and to determine correlations
df_train = X_train.join(y_train)

df_test = X_test.join(y_test)
# Out:
# C:\Users\sriha\OneDrive\Desktop\DS\My work\life-expectancy

# %%
df_train
# Out:
#                                Country  Year      Status  Adult Mortality  \
# 647                            Croatia  2009   Developed             19.0
# 1174                           Iceland  2011   Developed             51.0
# 234                            Belarus  2005  Developing            252.0
# 2789       United Republic of Tanzania  2004  Developing            454.0
# 2281                        Seychelles  2015  Developing            168.0
# ...                                ...   ...         ...              ...
# 1117                            Guyana  2004  Developing            237.0
# 594                            Comoros  2013  Developing            233.0
# 318   Bolivia (Plurinational State of)  2001  Developing            238.0
# 2263                           Senegal  2001  Developing            251.0
# 1092                     Guinea-Bissau  2013  Developing            279.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 647             9.0    12.21             2160.380199         97.0         2
# 1174            8.0     8.13                7.048093         93.0         0
# 234             1.0    11.01               45.650078         99.0         1
# 2789          100.0     3.81                0.000000         95.0      1419
# 2281            7.0     7.41                0.000000         98.0         0
# ...             ...      ...                     ...          ...       ...
# 1117            1.0     7.84                1.776181         91.0         0
# 594             1.0     0.01               61.574436         88.0         0
# 318            14.0     2.20                0.000000         77.0         0
# 2263           26.0     0.34                6.064221         89.0     24789
# 1092            4.0     0.01                8.200637         87.0         0
#
#       under-five deaths   ...  Total expenditure  Diphtheria    HIV/AIDS  \
# 647                 10.0  ...               8.18         96.0        0.1
# 1174                 9.5  ...               8.65         95.0        0.1
# 234                  1.0  ...               6.89         99.0        0.1
# 2789               154.0  ...               4.10         95.0       10.8
# 2281                 8.0  ...               3.73         97.0        0.1
# ...                  ...  ...                ...          ...        ...
# 1117                 1.0  ...               5.73         91.0        1.9
# 594                  2.0  ...               6.51         87.0        0.8
# 318                 19.0  ...               6.31         71.0        0.1
# 2263                49.0  ...               4.98         52.0        0.6
# 1092                 6.0  ...               6.14         87.0        4.5
#
#                GDP  Population   thinness  1-19 years   thinness 5-9 years  \
# 647   14157.144160    442978.0                    1.7                  1.6
# 1174     46.217000     31914.0                    0.9                  0.9
# 234    3126.717670   9663915.0                    2.3                  2.5
# 2789   1360.094916   1239196.0                    7.8                  7.8
# 2281   1539.464000     93419.0                    5.7                  6.0
# ...            ...         ...                    ...                  ...
# 1117    145.588610    751652.0                    5.8                  5.6
# 594     834.341949      7415.0                    6.8                  6.6
# 318    1417.265820   1352219.0                    1.5                  1.4
# 2263    481.287397   1134497.0                   12.1                 12.1
# 1092     61.566347   1681495.0                    7.5                  7.3
#
#       Income composition of resources  Schooling  Life expectancy
# 647                             0.803      14.20              76.3
# 1174                            0.894      18.60              82.1
# 234                             0.713      14.40              68.1
# 2789                            0.649      12.05              51.5
# 2281                            0.781      14.10              73.2
# ...                               ...        ...               ...
# 1117                            0.613      11.20              65.1
# 594                             0.490      10.90              62.9
# 318                             0.607      13.70              63.3
# 2263                            0.381       5.40              57.9
# 1092                            0.415       9.10              58.1
#
# [2196 rows x 21 columns]

# %%
df_test
# Out:
#                                     Country  Year      Status  \
# 1610                               Maldives  2007  Developing
# 2622                                   Togo  2010  Developing
# 642                                 Croatia  2014   Developed
# 1192                                  India  2009  Developing
# 2553                             Tajikistan  2015  Developing
# ...                                     ...   ...         ...
# 340                                Botswana  2011  Developing
# 716   Democratic People's Republic of Korea  2004  Developing
# 660                                    Cuba  2012  Developing
# 655                                 Croatia  2001   Developed
# 1296                                  Italy  2001   Developed
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 1610             82.0            8.5     1.78                6.491489
# 2622            323.0           14.0     1.21               41.961455
# 642              97.0            7.0    12.14             1884.098811
# 1192              2.0         1300.0     2.50                0.844186
# 2553            161.0           10.0     0.35                0.000000
# ...               ...            ...      ...                     ...
# 340             325.0            2.0     5.76              668.956285
# 716             165.0           11.0     3.13                0.000000
# 660              96.0            1.0     4.16              742.196199
# 655             126.0            9.0    13.15              650.956798
# 1296             75.0            2.0     9.69                3.122230
#
#       Hepatitis B  Measles   under-five deaths   ...  Total expenditure  \
# 1610         98.0        20                10.0  ...               6.64
# 2622         83.0       120                21.0  ...               5.37
# 642          95.0         0                 8.5  ...               7.80
# 1192         37.0     56188              1700.0  ...               4.38
# 2553         96.0         3                11.0  ...               5.70
# ...           ...       ...                 ...  ...                ...
# 340          95.0         8                 3.0  ...               5.25
# 716          98.0         0                14.0  ...               5.69
# 660          96.0         0                 1.0  ...               8.59
# 655          97.0         8                10.0  ...               7.16
# 1296         95.0         0                 3.0  ...               8.11
#
#       Diphtheria    HIV/AIDS           GDP   Population  \
# 1610         98.0        0.1     52.862285        349.0
# 2622         83.0        3.8    487.923891     652952.0
# 642          95.0        0.1  13467.468270    4238389.0
# 1192         74.0        0.2     19.317765  121427132.0
# 2553         96.0        0.2    918.677154    8548651.0
# ...           ...        ...           ...          ...
# 340          95.0        5.5   7645.214690     251339.0
# 716          72.0        0.1   1360.094916    1239196.0
# 660          99.0        0.1   6425.941119    1739746.0
# 655          94.0        0.1   5245.421419        444.0
# 1296         93.0        0.1     24.819000     569741.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 1610                   14.3                 14.4
# 2622                    7.3                  7.2
# 642                     1.5                  1.5
# 1192                   27.0                 27.8
# 2553                    3.6                  3.7
# ...                     ...                  ...
# 340                     7.7                  7.4
# 716                     5.7                  5.7
# 660                     3.4                  3.2
# 655                     2.0                  2.0
# 1296                    0.5                  0.5
#
#       Income composition of resources  Schooling  Life expectancy
# 1610                            0.632      11.90              75.4
# 2622                            0.449      11.00              57.4
# 642                             0.820      15.10              77.8
# 1192                            0.563      10.50              66.0
# 2553                            0.625      11.30              69.7
# ...                               ...        ...               ...
# 340                             0.678      12.40              62.2
# 716                             0.649      12.05              68.4
# 660                             0.778      15.70              78.7
# 655                             0.749      12.30              74.9
# 1296                            0.828      14.90              79.8
#
# [732 rows x 21 columns]

# %% [markdown]
# # Understanding the Features

# %%
corr1 = df_train.corr()['Life expectancy '].sort_values(ascending=False)
corr1
# Out:
# Life expectancy                    1.000000
# Schooling                          0.723812
# Income composition of resources    0.690221
# Diphtheria                         0.491289
# Polio                              0.482098
# GDP                                0.431693
# Alcohol                            0.407427
# percentage expenditure             0.383065
# Hepatitis B                        0.315189
# Total expenditure                  0.226355
# Year                               0.168396
# Population                        -0.031016
# Measles                           -0.136541
# infant deaths                     -0.198382
# under-five deaths                 -0.228918
#  thinness 5-9 years               -0.462272
#  thinness  1-19 years             -0.467641
#  HIV/AIDS                         -0.554506
# Adult Mortality                   -0.700336
# Name: Life expectancy , dtype: float64

# %% [markdown]
# # Feature Engineering
#
# ### 1. Transformation
#
# - EDA revealed that many features were skewed (i.e. not normally distributed). Here we will use scipy.stats to figure out which features are skewed and apply a log transform to reduce the skew. There are other methods to deal with skew, but we will stick to this simple method for now.
#
# - Applying the log transform did help reduce the skew, which is likely to improve performance.
#
# - Of note, based on our criteria, the target variable was not transformed, so we will not have to apply an inverse log pprior to making predictions.
#
#
#
# ### 2. Encoding
#
# - We have one categorical feature ('Status') which we will encode
#
# ### 3. Feature selection
#
# - EDA reveled that some features were strongly correlated to each other. We may later choose to drop these features to improve performance. For now we will leave them in.

# %%
def find_skew(dataset, show=True, col_names=False):
  df_skew = pd.DataFrame(dataset.select_dtypes(np.number).columns, columns=['Feature'])
  df_skew['Skew'] = df_skew['Feature'].apply(lambda feature: scipy.stats.skew(dataset[feature]))
  df_skew['Absolute Skew'] = df_skew['Skew'].apply(abs)
  df_skew['Skewed'] = df_skew['Absolute Skew'].apply(lambda x: True if x >= 0.65 else False)

  if show:
    from IPython.display import display
    display(df_skew)

  if col_names:
    return df_skew[df_skew['Absolute Skew'] >= 0.65]['Feature'].values

find_skew(df_train)
# Out:
#                             Feature       Skew  Absolute Skew  Skewed
# 0                              Year   0.011315       0.011315   False
# 1                   Adult Mortality   1.142866       1.142866    True
# 2                     infant deaths  10.004900      10.004900    True
# 3                           Alcohol   0.571788       0.571788   False
# 4            percentage expenditure   4.549512       4.549512    True
# 5                       Hepatitis B  -1.776575       1.776575    True
# 6                          Measles   10.124506      10.124506    True
# 7                under-five deaths    9.547769       9.547769    True
# 8                             Polio  -2.007580       2.007580    True
# 9                 Total expenditure   0.547573       0.547573   False
# 10                      Diphtheria   -1.988926       1.988926    True
# 11                         HIV/AIDS   5.276738       5.276738    True
# 12                              GDP   3.464364       3.464364    True
# 13                       Population  19.000081      19.000081    True
# 14             thinness  1-19 years   1.603656       1.603656    True
# 15               thinness 5-9 years   1.671065       1.671065    True
# 16  Income composition of resources  -1.166076       1.166076    True
# 17                        Schooling  -0.616657       0.616657   False
# 18                 Life expectancy   -0.618601       0.618601   False

# %%
df = df_train.copy()
skewed_cols = find_skew(df, show=False, col_names=True)

for col in skewed_cols:
  df[col] = np.log1p(df[col])

find_skew(df)
# Out:
#                             Feature      Skew  Absolute Skew  Skewed
# 0                              Year  0.011315       0.011315   False
# 1                   Adult Mortality -1.083005       1.083005    True
# 2                     infant deaths  0.805773       0.805773    True
# 3                           Alcohol  0.571788       0.571788   False
# 4            percentage expenditure -0.074512       0.074512   False
# 5                       Hepatitis B -2.847335       2.847335    True
# 6                          Measles   0.529936       0.529936   False
# 7                under-five deaths   0.720237       0.720237    True
# 8                             Polio -3.155433       3.155433    True
# 9                 Total expenditure  0.547573       0.547573   False
# 10                      Diphtheria  -3.090630       3.090630    True
# 11                         HIV/AIDS  2.062929       2.062929    True
# 12                              GDP -0.149385       0.149385   False
# 13                       Population -0.704426       0.704426    True
# 14             thinness  1-19 years  0.130621       0.130621   False
# 15               thinness 5-9 years  0.101263       0.101263   False
# 16  Income composition of resources -1.662477       1.662477    True
# 17                        Schooling -0.616657       0.616657   False
# 18                 Life expectancy  -0.618601       0.618601   False

# %%
del df

# %% [markdown]
# # Create EngineerFeatures Object

# %%
class EngineerFeatures():

    def __init__(self):
        pass

    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None): 
        X_new = X.copy()

        # Drop correlated features
        cols_to_drop = [
            
        ]
        X_new = X_new.drop(cols_to_drop, axis=1)

        # Feature transformations for numeric features
        skewed_cols = find_skew(X_new, show=False, col_names=True)

        for col in skewed_cols:
            X_new[col] = np.log1p(X_new[col])

        # Feature encoding
        cols_to_encode = [
            'Status'
        ]
        
        X_new = pd.get_dummies(X_new, columns=cols_to_encode, drop_first=True)

        return X_new

    def fit_transform(self, X, y=None):
        return self.fit(X).transform(X)

# %%
engg = EngineerFeatures()

df_train_engineered = engg.fit_transform(df_train)
df_test_engineered = engg.fit_transform(df_test)

# %%
# Note that the targeet variable is unchanged, so we can proceed with saving just the features
X_train_engineered = df_train_engineered.drop('Life expectancy ', axis=1)
X_test_engineered = df_test_engineered.drop('Life expectancy ', axis=1)

# %%
X_train_engineered.head()
# Out:
#                           Country  Year  Adult Mortality  infant deaths  \
# 647                       Croatia  2009         2.995732       2.302585
# 1174                      Iceland  2011         3.951244       2.197225
# 234                       Belarus  2005         5.533389       0.693147
# 2789  United Republic of Tanzania  2004         6.120297       4.615121
# 2281                   Seychelles  2015         5.129899       2.079442
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 647     12.21                7.678502     4.584967  1.098612
# 1174     8.13                2.085435     4.543295  0.000000
# 234     11.01                3.842675     4.605170  0.693147
# 2789     3.81                0.000000     4.564348  7.258412
# 2281     7.41                0.000000     4.595120  0.000000
#
#       under-five deaths      Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# 647             2.397895  4.574711               8.18     4.574711    0.09531
# 1174            2.351375  4.564348               8.65     4.564348    0.09531
# 234             0.693147  4.595120               6.89     4.605170    0.09531
# 2789            5.043425  4.564348               4.10     4.564348    2.46810
# 2281            2.197225  4.584967               3.73     4.584967    0.09531
#
#            GDP  Population   thinness  1-19 years   thinness 5-9 years  \
# 647   9.558045   13.001278               0.993252             0.955511
# 1174  3.854754   10.370831               0.641854             0.641854
# 234   8.048059   16.083910               1.193922             1.252763
# 2789  7.216045   14.029974               2.174752             2.174752
# 2281  7.339839   11.444861               1.902108             1.945910
#
#       Income composition of resources  Schooling  Status_Developing
# 647                          0.589452      14.20                  0
# 1174                         0.638691      18.60                  0
# 234                          0.538246      14.40                  1
# 2789                         0.500169      12.05                  1
# 2281                         0.577175      14.10                  1

# %%
X_test_engineered.head()
# Out:
#          Country  Year  Adult Mortality  infant deaths  Alcohol  \
# 1610    Maldives  2007         4.418841       2.251292     1.78
# 2622        Togo  2010         5.780744       2.708050     1.21
# 642      Croatia  2014         4.584967       2.079442    12.14
# 1192       India  2009         1.098612       7.170888     2.50
# 2553  Tajikistan  2015         5.087596       2.397895     0.35
#
#       percentage expenditure  Hepatitis B   Measles   under-five deaths   \
# 1610                2.013768     4.595120   3.044522            2.397895
# 2622                3.760303     4.430817   4.795791            3.091042
# 642                 7.541736     4.564348   0.000000            2.251292
# 1192                0.612038     3.637586  10.936476            7.438972
# 2553                0.000000     4.574711   1.386294            2.484907
#
#          Polio  Total expenditure  Diphtheria    HIV/AIDS       GDP  \
# 1610  4.595120           2.033398     4.595120   0.095310  3.986431
# 2622  4.430817           1.851599     4.430817   1.568616  6.192207
# 642   4.564348           2.174752     4.564348   0.095310  9.508107
# 1192  4.304065           1.682688     4.317488   0.182322  3.011496
# 2553  4.574711           1.902108     4.574711   0.182322  6.824023
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 1610    5.857933               2.727853             2.734368
# 2622   13.389260               2.116256             2.104134
# 642    15.259694               0.916291             0.916291
# 1192   18.614825               3.332205             3.360375
# 2553   15.961284               1.526056             1.547563
#
#       Income composition of resources  Schooling  Status_Developing
# 1610                         0.489806       11.9                  1
# 2622                         0.370874       11.0                  1
# 642                          0.598837       15.1                  0
# 1192                         0.446607       10.5                  1
# 2553                         0.485508       11.3                  1

# %% [markdown]
# # Save Engineered Data

# %%
# pickle engineered train data
X_train_engineered.to_pickle('Data/X_train_engineered.pkl')

# pickle engineered test data
X_test_engineered.to_pickle('Data/X_test_engineered.pkl')
